# %%
import json
import networkx as nx
from community import community_louvain

# Load the data from output1.json
with open('./output1.json', 'r') as f:
    data = json.load(f)

# Initialize nodes and links
nodes = []
links = []


def check_node_or_add(node):
    if any(node['id'] == n['id'] for n in nodes):
        for n in nodes:
            if n['id'] == node['id']:
                n['connections'] += 1
    else:
        nodes.append(node)

def check_link_or_add(link):
    if any(link['source'] == n['id'] for n in nodes) and any(link['target'] == n['id'] for n in nodes):
        if any(link['source'] == l['source'] and link['target'] == l['target'] for l in links):
            for l in links:
                if l['source'] == link['source'] and l['target'] == link['target']:
                    l['value'] += 1
        else:
            links.append(link)       

# Iterate over all keys in the JSON object
for key in data.keys():
    temp_item = {"id": key, "group": 1, "connections": len(data[key])}
    

    check_node_or_add(temp_item)
    for item in data[key]:
        temp_item = {"id": item['word'], "group": 1, "connections": 1}
        check_node_or_add(temp_item)
        temp_link = {"source": key, "target": item['word'], "value": 1}
        check_link_or_add(temp_link)

# sort the nodes by connections
nodes = sorted(nodes, key=lambda k: k['connections'], reverse=True)[:50]
links = sorted(links, key=lambda k: k['value'], reverse=True)

print("Number of nodes: ", len(nodes))
print(nodes)

print("Number of links: ", len(links))
print(links)
# Create a graph from the nodes and links
G = nx.Graph()

# Add nodes to the graph
for node in nodes:
    G.add_node(node['id'])

# Add edges to the graph
for link in links:
    if link['source'] in G.nodes and link['target'] in G.nodes:
        G.add_edge(link['source'], link['target'])

# Detect communities
communities = community_louvain.best_partition(G)

# Add community information to nodes
for node in nodes:
    node['group'] = communities[node['id']]

# Now, nodes are grouped based on their interrelated connections
print(nodes)

# save the nodes and links to a JSON file
with open('formatted_output.json', 'w') as f:
    json.dump({"nodes": nodes, "links": links}, f)
# Out:
# Number of nodes:  50
# [{'id': 'brain', 'group': 1, 'connections': 283}, {'id': 'adolesc', 'group': 1, 'connections': 5}, {'id': 'develop', 'group': 1, 'connections': 5}, {'id': 'chang', 'group': 1, 'connections': 5}, {'id': 'activ', 'group': 1, 'connections': 5}, {'id': 'prune', 'group': 1, 'connections': 5}, {'id': 'myelin', 'group': 1, 'connections': 5}, {'id': 'c', 'group': 1, 'connections': 4}, {'id': 'matur', 'group': 1, 'connections': 4}, {'id': 'function', 'group': 1, 'connections': 4}, {'id': 'examin', 'group': 1, 'connections': 4}, {'id': 'neuron', 'group': 1, 'connections': 4}, {'id': 'synapt', 'group': 1, 'connections': 4}, {'id': 'make', 'group': 1, 'connections': 4}, {'id': 'call', 'group': 1, 'connections': 4}, {'id': 'experi', 'group': 1, 'connections': 4}, {'id': 'cognit', 'group': 1, 'connections': 4}, {'id': 'time', 'group': 1, 'connections': 3}, {'id': 'ofimport', 'group': 1, 'connections': 3}, {'id': 'structur', 'group': 1, 'connections': 3}, {'id': 'scientist', 'group': 1, 'connections': 3}, {'id': 'begin', 'group': 1, 'connections': 3}, {'id': 'understand', 'group': 1, 'connections': 3}, {'id': 'imag', 'group': 1, 'connections': 3}, {'id': 'research', 'group': 1, 'connections': 3}, {'id': 'teenag', 'group': 1, 'connections': 3}, {'id': 'dramat', 'group': 1, 'connections': 3}, {'id': 'fmri', 'group': 1, 'connections': 3}, {'id': 'region', 'group': 1, 'connections': 3}, {'id': 'part', 'group': 1, 'connections': 3}, {'id': 'associ', 'group': 1, 'connections': 3}, {'id': 'differ', 'group': 1, 'connections': 3}, {'id': 'reflect', 'group': 1, 'connections': 3}, {'id': 'instanc', 'group': 1, 'connections': 3}, {'id': 'larger', 'group': 1, 'connections': 3}, {'id': 'aspect', 'group': 1, 'connections': 3}, {'id': 'may', 'group': 1, 'connections': 3}, {'id': 'synaps', 'group': 1, 'connections': 3}, {'id': 'continu', 'group': 1, 'connections': 3}, {'id': 'process', 'group': 1, 'connections': 3}, {'id': 'like', 'group': 1, 'connections': 3}, {'id': 'plastic', 'group': 1, 'connections': 3}, {'id': 'reward', 'group': 1, 'connections': 3}, {'id': 'implic', 'group': 1, 'connections': 3}, {'id': 'control', 'group': 1, 'connections': 3}, {'id': 'practic', 'group': 1, 'connections': 3}, {'id': 'emot', 'group': 1, 'connections': 3}, {'id': 'studi', 'group': 1, 'connections': 3}, {'id': 'f', 'group': 1, 'connections': 3}, {'id': 'point', 'group': 1, 'connections': 3}]
# Number of links:  582
# [{'source': 'brain', 'target': 'c', 'value': 1}, {'source': 'brain', 'target': 'demystifi', 'value': 1}, {'source': 'brain', 'target': 'adolesc', 'value': 1}, {'source': 'brain', 'target': 'laurenc', 'value': 1}, {'source': 'brain', 'target': 'steinberg', 'value': 1}, {'source': 'brain', 'target': 'matur', 'value': 1}, {'source': 'brain', 'target': 'one', 'value': 1}, {'source': 'brain', 'target': 'moment', 'value': 1}, {'source': 'brain', 'target': 'frustratingli', 'value': 1}, {'source': 'brain', 'target': 'immatur', 'value': 1}, {'source': 'brain', 'target': 'next', 'value': 1}, {'source': 'brain', 'target': 'natur', 'value': 1}, {'source': 'brain', 'target': 'develop', 'value': 1}, {'source': 'brain', 'target': 'help', 'value': 1}, {'source': 'brain', 'target': 'explain', 'value': 1}, {'source': 'brain', 'target': 'addit', 'value': 1}, {'source': 'brain', 'target': 'transit', 'value': 1}, {'source': 'brain', 'target': 'time', 'value': 1}, {'source': 'brain', 'target': 'ofimport', 'value': 1}, {'source': 'brain', 'target': 'chang', 'value': 1}, {'source': 'brain', 'target': 'structur', 'value': 1}, {'source': 'brain', 'target': 'function', 'value': 1}, {'source': 'brain', 'target': 'scientist', 'value': 1}, {'source': 'brain', 'target': 'begin', 'value': 1}, {'source': 'brain', 'target': 'understand', 'value': 1}, {'source': 'brain', 'target': 'psycholog', 'value': 1}, {'source': 'brain', 'target': 'link', 'value': 1}, {'source': 'brain', 'target': 'brain', 'value': 1}, {'source': 'brain', 'target': 'imag', 'value': 1}, {'source': 'brain', 'target': 'technolog', 'value': 1}, {'source': 'brain', 'target': 'could', 'value': 1}, {'source': 'brain', 'target': 'specula', 'value': 1}, {'source': 'brain', 'target': 'work', 'value': 1}, {'source': 'brain', 'target': 'howev', 'value': 1}, {'source': 'brain', 'target': 'scanner', 'value': 1}, {'source': 'brain', 'target': 'use', 'value': 1}, {'source': 'brain', 'target': 'identifi', 'value': 1}, {'source': 'brain', 'target': 'tumor', 'value': 1}, {'source': 'brain', 'target': 'ligament', 'value': 1}, {'source': 'brain', 'target': 'research', 'value': 1}, {'source': 'brain', 'target': 'see', 'value': 1}, {'source': 'brain', 'target': 'insid', 'value': 1}, {'source': 'brain', 'target': 'watch', 'value': 1}, {'source': 'brain', 'target': 'happen', 'value': 1}, {'source': 'brain', 'target': 'teenag', 'value': 1}, {'source': 'brain', 'target': 'think', 'value': 1}, {'source': 'brain', 'target': 'know', 'value': 1}, {'source': 'brain', 'target': 'life', 'value': 1}, {'source': 'brain', 'target': 'period', 'value': 1}, {'source': 'brain', 'target': 'character', 'value': 1}, {'source': 'brain', 'target': 'dramat', 'value': 1}, {'source': 'brain', 'target': 'weve', 'value': 1}, {'source': 'brain', 'target': 'learn', 'value': 1}, {'source': 'brain', 'target': 'fmri', 'value': 1}, {'source': 'brain', 'target': 'greater', 'value': 1}, {'source': 'brain', 'target': 'interconnected', 'value': 1}, {'source': 'brain', 'target': 'among', 'value': 1}, {'source': 'brain', 'target': 'variou', 'value': 1}, {'source': 'brain', 'target': 'region', 'value': 1}, {'source': 'brain', 'target': 'allow', 'value': 1}, {'source': 'brain', 'target': 'better', 'value': 1}, {'source': 'brain', 'target': 'commun', 'value': 1}, {'source': 'brain', 'target': 'part', 'value': 1}, {'source': 'brain', 'target': 'associ', 'value': 1}, {'source': 'brain', 'target': 'differ', 'value': 1}, {'source': 'brain', 'target': 'exampl', 'value': 1}, {'source': 'brain', 'target': 'connect', 'value': 1}, {'source': 'brain', 'target': 'respons', 'value': 1}, {'source': 'brain', 'target': 'logic', 'value': 1}, {'source': 'brain', 'target': 'reason', 'value': 1}, {'source': 'brain', 'target': 'becom', 'value': 1}, {'source': 'brain', 'target': 'sinc', 'value': 1}, {'source': 'brain', 'target': 'explos', 'value': 1}, {'source': 'brain', 'target': 'grown', 'value': 1}, {'source': 'brain', 'target': 'breathtak', 'value': 1}, {'source': 'brain ...
# [{'id': 'brain', 'group': 0, 'connections': 283}, {'id': 'adolesc', 'group': 3, 'connections': 5}, {'id': 'develop', 'group': 2, 'connections': 5}, {'id': 'chang', 'group': 3, 'connections': 5}, {'id': 'activ', 'group': 3, 'connections': 5}, {'id': 'prune', 'group': 3, 'connections': 5}, {'id': 'myelin', 'group': 3, 'connections': 5}, {'id': 'c', 'group': 3, 'connections': 4}, {'id': 'matur', 'group': 3, 'connections': 4}, {'id': 'function', 'group': 1, 'connections': 4}, {'id': 'examin', 'group': 3, 'connections': 4}, {'id': 'neuron', 'group': 3, 'connections': 4}, {'id': 'synapt', 'group': 3, 'connections': 4}, {'id': 'make', 'group': 3, 'connections': 4}, {'id': 'call', 'group': 3, 'connections': 4}, {'id': 'experi', 'group': 3, 'connections': 4}, {'id': 'cognit', 'group': 3, 'connections': 4}, {'id': 'time', 'group': 1, 'connections': 3}, {'id': 'ofimport', 'group': 1, 'connections': 3}, {'id': 'structur', 'group': 1, 'connections': 3}, {'id': 'scientist', 'group': 1, 'connections': 3}, {'id': 'begin', 'group': 3, 'connections': 3}, {'id': 'understand', 'group': 1, 'connections': 3}, {'id': 'imag', 'group': 1, 'connections': 3}, {'id': 'research', 'group': 1, 'connections': 3}, {'id': 'teenag', 'group': 2, 'connections': 3}, {'id': 'dramat', 'group': 3, 'connections': 3}, {'id': 'fmri', 'group': 1, 'connections': 3}, {'id': 'region', 'group': 1, 'connections': 3}, {'id': 'part', 'group': 1, 'connections': 3}, {'id': 'associ', 'group': 1, 'connections': 3}, {'id': 'differ', 'group': 1, 'connections': 3}, {'id': 'reflect', 'group': 1, 'connections': 3}, {'id': 'instanc', 'group': 1, 'connections': 3}, {'id': 'larger', 'group': 1, 'connections': 3}, {'id': 'aspect', 'group': 1, 'connections': 3}, {'id': 'may', 'group': 1, 'connections': 3}, {'id': 'synaps', 'group': 3, 'connections': 3}, {'id': 'continu', 'group': 3, 'connections': 3}, {'id': 'process', 'group': 3, 'connections': 3}, {'id': 'like', 'group': 3, 'connections': 3}, {'id': 'plastic', 'group': 3, 'connections': 3}, {'id': 'reward', 'group': 3, 'connections': 3}, {'id': 'implic', 'group': 1, 'connections': 3}, {'id': 'control', 'group': 3, 'connections': 3}, {'id': 'practic', 'group': 3, 'connections': 3}, {'id': 'emot', 'group': 1, 'connections': 3}, {'id': 'studi', 'group': 1, 'connections': 3}, {'id': 'f', 'group': 1, 'connections': 3}, {'id': 'point', 'group': 3, 'connections': 3}]
