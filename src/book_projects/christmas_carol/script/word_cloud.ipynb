# %%
import pandas as pd
import json
import re
from general_functions.file_operations import write_json_file

# Read the csv file
df = pd.read_csv('../data/christmas_carol.csv')

# Convert the dataframe to json
data = json.loads(df.to_json(orient='records'))

def remove_bracket_content(text):
    # This will remove content within any type of brackets, including nested brackets
    return re.sub(r'\[[^\]]*\]', '', text)


only_dialogues = []
only_dialogues_without_sound_descriptions = []
for i in range(len(data)):
    # print(data[i])
    if data[i]["type"] == "dialogue":
        only_dialogues.append(data[i])
        data[i]["text"] = remove_bracket_content(data[i]["text"])
        only_dialogues_without_sound_descriptions.append(data[i])
        

# Write the json file
write_json_file('../data/christmas_carol_only_dialogues.json', only_dialogues)
write_json_file('../data/christmas_carol_only_dialogues_without_sound_descriptions.json', only_dialogues_without_sound_descriptions)
# Out:
# Successfully written to file.
# Successfully written to file.

# %%
import json
from collections import Counter
import re
from general_functions.translation import translate_to_spanish
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from general_functions.file_operations import write_json_file


stop_words = set(stopwords.words('english'))

# POS Tagging to general category mapping
POS_MAP = {
    'NN': 'noun', 'NNS': 'noun', 'NNP': 'noun', 'NNPS': 'noun',
    'VB': 'verb', 'VBD': 'verb', 'VBG': 'verb', 'VBN': 'verb', 'VBP': 'verb', 'VBZ': 'verb',
    'JJ': 'adjective', 'JJR': 'adjective', 'JJS': 'adjective',
    'RB': 'adverb', 'RBR': 'adverb', 'RBS': 'adverb',
    'IN': 'preposition',
    'DT': 'determiner',
    'PRP': 'pronoun', 'PRP$': 'pronoun', 'WP': 'pronoun', 'WP$': 'pronoun',
    'MD': 'modal',
    'CC': 'conjunction',
    'CD': 'number',
    'EX': 'existential',
    'FW': 'foreign',
    'POS': 'possessive',
    'PDT': 'predeterminer',
    'RP': 'particle',
    'SYM': 'symbol',
    'TO': 'to',
    'UH': 'interjection',
    'WRB': 'wh-adverb'
}

def get_pos(word):
    tag = pos_tag([word])[0][1]
    return POS_MAP.get(tag, 'unknown')


def count_words(text):
    words = re.findall(r'\w+', text.lower())
    return Counter(words)

def find_scene(scenes, scene_name):
    for scene in scenes:
        if scene['scene'] == scene_name:
            return scene
    return None

def find_act(acts, act_name):
    for act in acts:
        if act['act'] == act_name:
            return act
    return None

def process_dialogues(dialogues, categories, top_n):
    acts = []
    translations = {}  # Store previously translated words

    for i, dialogue in enumerate(dialogues):
        print(f"Processing dialogue {i+1} of {len(dialogues)}...")

        act_name = dialogue['act']
        scene_name = dialogue['scene']
        text = dialogue['text']

        act = find_act(acts, act_name)
        if not act:
            act = {'act': act_name, 'scenes': []}
            acts.append(act)

        scene = find_scene(act['scenes'], scene_name)
        if not scene:
            scene = {'scene': scene_name, 'words': []}
            act['scenes'].append(scene)

        word_tokens = word_tokenize(text.lower())
        filtered_text = [word for word in word_tokens if word not in stop_words]
        
        for word in filtered_text:
            pos = get_pos(word)
            if pos in categories:
                word_counts = count_words(word)
                for word, count in word_counts.items():
                    word_entry = next((entry for entry in scene['words'] if entry['word'] == word), None)
                    if word_entry:
                        word_entry['value'] += count
                        if text not in word_entry['utterances']:
                            word_entry['utterances'].append(text)
                    else:
                        scene['words'].append({'word': word, 'value': count, 'utterances': [text], 'category': pos})

        # Sort the words in the scene based on their count and keep only the top 'n'
        scene['words'] = sorted(scene['words'], key=lambda x: x['value'], reverse=True)[:top_n]

        # Translate the top 'n' words
        for word_entry in scene['words']:
            word = word_entry['word']
            if word not in translations:
                print(f"Translating word '{word}'...")
                translations[word] = translate_to_spanish(word)
            word_entry['translation'] = translations[word]

    print("Processing completed.")
    return acts

with open('../data/christmas_carol_only_dialogues_without_sound_descriptions.json') as f:
    dialogues = json.load(f)
    dialogues_of_scrooge = [dialogue for dialogue in dialogues if dialogue['character'] == 'Scrooge']
    categories =["noun", "adjective", "adverb", "verb", "pronoun"]
    result = process_dialogues(dialogues_of_scrooge, categories, 100)
    write_json_file('../data/christmas_carol_scrooge_top_words.json', result)
# Out:
# Processing dialogue 1 of 182...
# Translating word 'owe'...
# Translating word 'money'...
# Translating word 'collect'...
# Translating word 'jailed'...
# Translating word 'due'...
# Processing dialogue 2 of 182...
# Translating word 'cratchit'...
# Translating word 'coal'...
# Translating word 'acting'...
# Translating word 'cold'...
# Translating word 'next'...
# Translating word 'asking'...
# Translating word 'replenish'...
# Translating word 'box'...
# Translating word 'well'...
# Translating word 'save'...
# Translating word 'breath'...
# Translating word 'prepared'...
# Translating word 'find'...
# Translating word 'employ'...
# Translating word 'elsewhere'...
# Processing dialogue 3 of 182...
# Translating word 'bah'...
# Translating word 'humbug'...
# Processing dialogue 4 of 182...
# Translating word 'merry'...
# Translating word 'christmas'...
# Translating word 'right'...
# Translating word 'reason'...
# Translating word 'poor'...
# Translating word 'enough'...
# Processing dialogue 5 of 182...
# Processing dialogue 6 of 182...
# Translating word 'time'...
# Translating word 'else'...
# Translating word 'eh'...
# Translating word 'live'...
# Translating word 'world'...
# Translating word 'fools'...
# Translating word 'christmastime'...
# Translating word 'paying'...
# Translating word 'bills'...
# Translating word 'finding'...
# Translating word 'year'...
# Translating word 'older'...
# Translating word 'hour'...
# Translating word 'richer'...
# Translating word 'work'...
# Translating word 'idiot'...
# Translating word 'goes'...
# Translating word 'lips'...
# Translating word 'boiled'...
# Translating word 'pudding'...
# Translating word 'buried'...
# Translating word 'stake'...
# Translating word 'holly'...
# Translating word 'heart'...
# Processing dialogue 7 of 182...
# Translating word 'keep'...
# Translating word 'nephew'...
# Translating word 'way'...
# Translating word 'let'...
# Translating word 'mine'...
# Processing dialogue 8 of 182...
# Translating word 'leave'...
# Translating word 'alone'...
# Translating word 'much'...
# Translating word 'good'...
# Translating word 'ever'...
# Translating word 'done'...
# Processing dialogue 9 of 182...
# Translating word 'hear'...
# Translating word 'sound'...
# Translating word 'losing'...
# Translating word 'situation'...
# Translating word 'quite'...
# Translating word 'powerful'...
# Translating word 'speaker'...
# Translating word 'sir'...
# Translating word 'wonder'...
# Translating word 'go'...
# Translating word 'parliament'...
# Processing dialogue 10 of 182...
# Translating word 'see'...
# Translating word 'rather'...
# Translating word 'dead'...
# Translating word 'family'...
# Processing dialogue 11 of 182...
# Translating word 'get'...
# Translating word 'married'...
# Processing dialogue 12 of 182...
# Translating word 'thing'...
# Translating word 'said'...
# Translating word 'entire'...
# Translating word 'lifetime'...
# Translating word 'even'...
# Translating word 'ridiculous'...
# Translating word 'afternoon'...
# Processing dialogue 13 of 182...
# Processing dialogue 14 of 182...
# Processing dialogue 15 of 182...
# Processing dialogue 16 of 182...
# Translating word 'fine'...
# Translating word 'perfect'...
# Translating word 'pair'...
# Translating word 'oh'...
# Translating word 'perfection'...
# Translating word 'husbands'...
# Translating word 'wives'...
# Translating word 'children'...
# Translating word 'support'...
# Translating word 'clerk'...
# Translating word 'earning'...
# Translating word 'fifteen'...
# Translating word 'shillings'...
# Translating word 'week'...
# Translating word 'talking'...
# Translating word 'retire'...
# Translating word 'bedlam'...
# Processing dialogue 17 of 182...
# Translating word 'years'...
# Processing dialogue 18 of 182...
# Processing dialogue 19 of 182...
# Processing dialogue 20 of 182...
# Processing dialogue 21 of 182...
# Processing dialogue 22 of 182...
# Processing dialogue 23 of 182...
# Processing dialogue 24 of 182...
# Translating word 'wish'...
# Processing dialogue 25 of 182...
# Translating word 'business'...
# Processing dialogue 26 of 182...
# Processing dialogue 27 of 182...
# Processing dialogue 28 of 182...
# Processing dialogue 29 of 182...
# Processing dialogue 30 of 182...
# Processing dialogue 31 of 182...
# Processing dialogue 32 of 182...
# Processing dialogue 33 of 182...
# Processing dialogue 34 of 182...
# Processing dialogue 35 of 182...
# Processing dialogue 36 of 182...
# Translating word 'light'...
# Translating word 'moon'...
# Translating word 'center'...
# Translating word 'eve'...
# Translating word 'black'...
# Translating word 'void'...
# Processing dialogue 37 of 182...
# Translating word 'pooh'...
# Processing dialogue 38 of 182...
# Processing dialogue 39 of 182...
# Translating word 'still'...
# Translating word 'happening'...
# Translating word 'believe'...
# Processing dialogue 40 of 182...
# Translating word 'want'...
# Processing dialogue 41 of 182...
# Processing dialogue 42 of 182...
# Processing dialogue 43 of 182...
# Translating word 'sit'...
# Processing dialogue 44 of 182...
# Processing dialogue 45 of 182...
# Processing dialogue 46 of 182...
# Translating word 'little'...
# Translating word 'affects'...
# Translating word 'slight'...
# Translating word 'disorder'...
# Translating word 'stomach'...
# Translating word 'makes'...
# Translating word 'cheat'...
# Translating word 'undigested'...
# Translating word 'bit'...
# Translating word 'beef'...
# Translating word 'blot'...
# Translating word 'mustard'...
# Translating word 'crumb'...
# Translating word 'cheese'...
# Translating word 'fragment'...
# Translating word 'underdone'...
# Translating word 'potato'...
# Translating word 'gravy'...
# Translating word 'grave'...
# Processing dialogue 47 of 182...
# Translating word 'tell'...
# Processing dialogue 48 of 182...
# Translating word 'mercy'...
# Translating word 'dreadful'...
# Translating word 'apparition'...
# Translating word 'trouble'...
# Processing dialogue 49 of 182...
# Translating word 'spirits'...
# Translating word 'walk'...
# Translating word 'earth'...
# Translating word 'come'...
# Processing dialogue 50 of 182...
# Translating word 'jacob'...
# Translating word 'old'...
# Translating word 'marley'...
# Translating word 'speak'...
# Translating word 'comfort'...
# Processing dialogue 51 of 182...
# Translating word 'always'...
# Translating word 'man'...
# Processing dialogue 52 of 182...
# Translating word 'hard'...
# Translating word 'flowery'...
# Translating word 'pray'...
# Processing dialogue 53 of 182...
# Translating word 'friend'...
# Translating word 'thank'...
# Translating word 'ee'...
# Processing dialogue 54 of 182...
# Translating word 'chance'...
# Translating word 'hope'...
# Translating word 'mentioned'...
# Processing dialogue 55 of 182...
# Translating word 'think'...
# Processing dialogue 56 of 182...
# Translating word 'take'...
# Translating word 'em'...
# Processing dialogue 57 of 182...
# Translating word 'imagine'...
# Translating word 'sorry'...
# Translating word 'frightened'...
# Translating word 'happened'...
# Translating word 'foulest'...
# Translating word 'dream'...
# Translating word 'mind'...
# Processing dialogue 58 of 182...
# Translating word 'possible'...
# Translating word 'night'...
# Translating word 'noon'...
# Translating word 'midnight'...
# Translating word 'past'...
# Translating word 'went'...
# Translating word 'bed'...
# Translating word 'icicle'...
# Translating word 'gotten'...
# Translating word 'clock'...
# Translating word 'works'...
# Translating word 'slept'...
# Translating word 'whole'...
# Translating word 'day'...
# Translating word 'far'...
# Translating word 'anything'...
# Translating word 'sun'...
# Translating word 'twelve'...
# Translating word 'quiet'...
# Translating word 'normal'...
# Translating word 'season'...
# Translating word 'certainly'...
# Translating word 'afford'...
# Translating word 'lose'...
# Translating word 'days'...
# Translating word 'securities'...
# Translating word 'promissory'...
# Translating word 'notes'...
# Translating word 'interest'...
# Translating word 'investments'...
# Translating word 'things'...
# Translating word 'happen'...
# Translating word 'daylight'...
# Processing dialogue 59 of 182...
# Translating word 'quarter'...
# Translating word 'ghostly'...
# Translating word 'friends'...
# Translating word 'chime'...
# Translating word 'half'...
# Translating word 'heavy'...
# Translating word 'bell'...
# Translating word 'game'...
# Translating word 'senses'...
# Translating word 'perhaps'...
# Translating word 'allowed'...
# Translating word 'short'...
# Translating word 'doze'...
# Processing dialogue 60 of 182...
# Translating word 'hand'...
# Translating word 'owns'...
# Translating word 'hello'...
# Processing dialogue 61 of 182...
# Translating word 'spirit'...
# Translating word 'whose'...
# Translating word 'coming'...
# Translating word 'foretold'...
# Processing dialogue 62 of 182...
# Processing dialogue 63 of 182...
# Translating word 'long'...
# Processing dialogue 64 of 182...
# Translating word 'ask'...
# Translating word 'please'...
# Processing dialogue 65 of 182...
# Translating word 'really'...
# Translating word 'ungrateful'...
# Translating word 'understand'...
# Translating word 'plenty'...
# Translating word 'obliged'...
# Translating word 'concern'...
# Translating word 'kind'...
# Translating word 'better'...
# Translating word 'welfare'...
# Translating word 'left'...
# Translating word 'altogether'...
# Translating word 'peacefully'...
# Processing dialogue 66 of 182...
# Processing dialogue 67 of 182...
# Translating word 'fly'...
# Translating word 'mortal'...
# Processing dialogue 68 of 182...
# Translating word 'heaven'...
# Translating word 'bred'...
# Translating word 'place'...
# Translating word 'boy'...
# Processing dialogue 69 of 182...
# Translating word 'nothing'...
# Translating word 'cheek'...
# Translating word 'blemish'...
# Translating word 'skin'...
# Translating word 'eating'...
# Translating word 'overmuch'...
# Translating word 'grease'...
# Translating word 'lead'...
# Translating word 'quickly'...
# Translating word 'stagnant'...
# Translating word 'unbearable'...
# Translating word 'recollect'...
# Processing dialogue 70 of 182...
# Translating word 'remember'...
# Translating word 'know'...
# Translating word 'blindfolded'...
# Translating word 'bridge'...
# Translating word 'church'...
# Translating word 'winding'...
# Translating word 'river'...
# Processing dialogue 71 of 182...
# Translating word 'listen'...
# Translating word 'men'...
# Translating word 'beauty'...
# Translating word 'song'...
# Processing dialogue 72 of 182...
# Translating word 'none'...
# Processing dialogue 73 of 182...
# Translating word 'look'...
# Processing dialogue 74 of 182...
# Translating word 'lived'...
# Translating word 'head'...
# Translating word 'ah'...
# Translating word 'late'...
# Translating word 'matter'...
# Processing dialogue 75 of 182...
# Translating word 'singing'...
# Translating word 'carol'...
# Translating word 'door'...
# Translating word 'last'...
# Translating word 'given'...
# Translating word 'something'...
# Processing dialogue 76 of 182...
# Translating word 'yes'...
# Processing dialogue 77 of 182...
# Processing dialogue 78 of 182...
# Translating word 'dear'...
# Translating word 'sister'...
# Translating word 'fan'...
# Translating word 'loved'...
# Processing dialogue 79 of 182...
# Processing dialogue 80 of 182...
# Translating word 'child'...
# Processing dialogue 81 of 182...
# Processing dialogue 82 of 182...
# Translating word 'apprenticed'...
# Processing dialogue 83 of 182...
# Translating word 'fezziwig'...
# Translating word 'bless'...
# Translating word 'alive'...
# Processing dialogue 84 of 182...
# Translating word 'quittin'...
# Processing dialogue 85 of 182...
# Translating word 'dick'...
# Translating word 'wilkins'...
# Translating word 'sure'...
# Translating word 'fellow'...
# Translating word 'prentice'...
# Translating word 'soul'...
# Translating word 'attached'...
# Processing dialogue 86 of 182...
# Translating word 'small'...
# Processing dialogue 87 of 182...
# Translating word 'make'...
# Translating word 'power'...
# Translating word 'us'...
# Translating word 'happy'...
# Translating word 'unhappy'...
# Translating word 'service'...
# Translating word 'burdensome'...
# Translating word 'pleasure'...
# Translating word 'toil'...
# Translating word 'happiness'...
# Translating word 'gave'...
# Translating word 'great'...
# Translating word 'cost'...
# Translating word 'fortune'...
# Processing dialogue 88 of 182...
# Translating word 'particular'...
# Processing dialogue 89 of 182...
# Translating word 'l'...
# Translating word 'able'...
# Translating word 'say'...
# Translating word 'word'...
# Processing dialogue 90 of 182...
# Processing dialogue 91 of 182...
# Processing dialogue 92 of 182...
# Processing dialogue 93 of 182...
# Processing dialogue 94 of 182...
# Processing dialogue 95 of 182...
# Processing dialogue 96 of 182...
# Processing dialogue 97 of 182...
# Processing dialogue 98 of 182...
# Processing dialogue 99 of 182...
# Translating word 'fool'...
# Processing dialogue 100 of 182...
# Processing dialogue 101 of 182...
# Processing dialogue 102 of 182...
# Processing dialogue 103 of 182...
# Processing dialogue 104 of 182...
# Translating word 'sleeping'...
# Translating word 'backwards'...
# Processing dialogue 105 of 182...
# Translating word 'heavens'...
# Translating word 'back'...
# Translating word 'forth'...
# Translating word 'absolutely'...
# Processing dialogue 106 of 182...
# Processing dialogue 107 of 182...
# Translating word 'checking'...
# Translating word 'anyone'...
# Processing dialogue 108 of 182...
# Translating word 'call'...
# Processing dialogue 109 of 182...
# Translating word 'never'...
# Processing dialogue 110 of 182...
# Translating word 'afraid'...
# Translating word 'many'...
# Translating word 'brothers'...
# Processing dialogue 111 of 182...
# Translating word 'tremendous'...
# Translating word 'provide'...
# Translating word 'conduct'...
# Translating word 'compulsion'...
# Translating word 'learnt'...
# Translating word 'lesson'...
# Translating word 'working'...
# Translating word 'tonight'...
# Translating word 'aught'...
# Translating word 'teach'...
# Translating word 'profit'...
# Processing dialogue 112 of 182...
# Translating word 'sprinkle'...
# Translating word 'torch'...
# Processing dialogue 113 of 182...
# Translating word 'people'...
# Translating word 'kindness'...
# Processing dialogue 114 of 182...
# Processing dialogue 115 of 182...
# Processing dialogue 116 of 182...
# Translating word 'mean'...
# Translating word 'home'...
# Processing dialogue 117 of 182...
# Processing dialogue 118 of 182...
# Translating word 'meager'...
# Translating word 'earnings'...
# Translating word 'foolishness'...
# Processing dialogue 119 of 182...
# Translating word 'shillings4'...
# Translating word 'gets'...
# Processing dialogue 120 of 182...
# Translating word 'tiny'...
# Translating word 'tim'...
# Processing dialogue 121 of 182...
# Translating word 'spared'...
# Processing dialogue 122 of 182...
# Translating word 'huh'...
# Translating word 'calls'...
# Processing dialogue 123 of 182...
# Translating word 'bob'...
# Translating word 'toast'...
# Processing dialogue 124 of 182...
# Processing dialogue 125 of 182...
# Translating word 'sight'...
# Translating word 'madam'...
# Processing dialogue 126 of 182...
# Translating word 'mrs'...
# Translating word 'toasting'...
# Processing dialogue 127 of 182...
# Translating word 'listening'...
# Translating word 'feel'...
# Translating word 'seen'...
# Processing dialogue 128 of 182...
# Translating word 'moved'...
# Translating word 'mines'...
# Processing dialogue 129 of 182...
# Processing dialogue 130 of 182...
# Translating word 'talk'...
# Processing dialogue 131 of 182...
# Translating word 'says'...
# Translating word 'true'...
# Processing dialogue 132 of 182...
# Translating word 'visible'...
# Translating word 'audible'...
# Translating word 'niece'...
# Processing dialogue 133 of 182...
# Translating word 'hair'...
# Translating word 'gone'...
# Translating word 'gray'...
# Translating word 'wrinkled'...
# Translating word 'lives'...
# Processing dialogue 134 of 182...
# Processing dialogue 135 of 182...
# Processing dialogue 136 of 182...
# Translating word 'refuge'...
# Translating word 'resource'...
# Processing dialogue 137 of 182...
# Processing dialogue 138 of 182...
# Translating word 'yet'...
# Translating word 'phantom'...
# Translating word 'show'...
# Translating word 'shadows'...
# Translating word 'ghost'...
# Translating word 'future'...
# Translating word 'fear'...
# Translating word 'specter'...
# Translating word 'purpose'...
# Translating word 'bear'...
# Translating word 'company'...
# Translating word 'waning'...
# Translating word 'fast'...
# Translating word 'precious'...
# Processing dialogue 139 of 182...
# Translating word 'businessmen'...
# Translating word 'streets'...
# Translating word 'death'...
# Processing dialogue 140 of 182...
# Translating word 'oooooooooooooooooooooooooooooo'...
# Translating word 'oooooooooooooooooo'...
# Processing dialogue 141 of 182...
# Translating word 'corpse'...
# Translating word 'life'...
# Translating word 'oooooooooooooooooooooooooooooooooooooo'...
# Translating word 'obscene'...
# Translating word 'demons'...
# Translating word 'market'...
# Translating word 'sell'...
# Translating word 'trimming'...
# Translating word 'this'...
# Translating word 'stripped'...
# Translating word 'bare'...
# Translating word 'holds'...
# Translating word 'parallel'...
# Translating word 'ends'...
# Processing dialogue 142 of 182...
# Translating word 'fearful'...
# Translating word 'leaving'...
# Translating word 'trust'...
# Processing dialogue 143 of 182...
# Translating word 'tenderness'...
# Translating word 'connected'...
# Translating word 'dark'...
# Translating word 'chamber'...
# Processing dialogue 144 of 182...
# Processing dialogue 145 of 182...
# Processing dialogue 146 of 182...
# Processing dialogue 147 of 182...
# Processing dialogue 148 of 182...
# Processing dialogue 149 of 182...
# Processing dialogue 150 of 182...
# Processing dialogue 151 of 182...
# Translating word 'give'...
# Translating word 'sign'...
# Processing dialogue 152 of 182...
# Translating word 'present'...
# Translating word 'strive'...
# Processing dialogue 153 of 182...
# Translating word 'praise'...
# Translating word 'knees'...
# Translating word 'torn'...
# Translating word 'wherever'...
# Translating word 'ye'...
# Translating word 'curtains'...
# Translating word 'rings'...
# Translating word 'dispelled'...
# Processing dialogue 154 of 182...
# Translating word 'hallo'...
# Translating word 'care'...
# Translating word 'everybody'...
# Translating word 'whoop'...
# Translating word 'baby'...
# Translating word 'feather'...
# Translating word 'angel'...
# Translating word 'schoolboy'...
# Translating word 'new'...
# Translating word 'month'...
# Translating word 'fig'...
# Translating word 'wreck'...
# Processing dialogue 155 of 182...
# Translating word 'hey'...
# Translating word 'today'...
# Processing dialogue 156 of 182...
# Translating word 'course'...
# Translating word 'missed'...
# Processing dialogue 157 of 182...
# Translating word 'name'...
# Translating word 'lad'...
# Processing dialogue 158 of 182...
# Translating word 'adam'...
# Translating word 'strong'...
# Translating word 'poulterer'...
# Translating word 'street'...
# Translating word 'corner'...
# Processing dialogue 159 of 182...
# Translating word 'prize'...
# Translating word 'turkey'...
# Translating word 'remarkable'...
# Translating word 'intelligent'...
# Translating word 'sold'...
# Translating word 'hanging'...
# Translating word 'big'...
# Processing dialogue 160 of 182...
# Translating word 'size'...
# Translating word 'bird'...
# Processing dialogue 161 of 182...
# Translating word 'buy'...
# Translating word 'earnest'...
# Translating word 'bring'...
# Translating word 'directions'...
# Translating word 'delivered'...
# Translating word 'gift'...
# Translating word 'shilling'...
# Translating word 'less'...
# Translating word 'minutes'...
# Translating word 'a'...
# Translating word 'crown'...
# Processing dialogue 162 of 182...
# Processing dialogue 163 of 182...
# Processing dialogue 164 of 182...
# Processing dialogue 165 of 182...
# Processing dialogue 166 of 182...
# Processing dialogue 167 of 182...
# Processing dialogue 168 of 182...
# Processing dialogue 169 of 182...
# Processing dialogue 170 of 182...
# Processing dialogue 171 of 182...
# Processing dialogue 172 of 182...
# Processing dialogue 173 of 182...
# Processing dialogue 174 of 182...
# Processing dialogue 175 of 182...
# Processing dialogue 176 of 182...
# Processing dialogue 177 of 182...
# Processing dialogue 178 of 182...
# Processing dialogue 179 of 182...
# Processing dialogue 180 of 182...
# Processing dialogue 181 of 182...
# Processing dialogue 182 of 182...
# Processing completed.
# Successfully written to file.
